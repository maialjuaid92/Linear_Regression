# %% [markdown]
# ### Importing libraries

# %%
from bs4 import BeautifulSoup
import requests
import time, os
import pandas as pd

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

# %%
#locating driver path to the chromedriver
chromedriver = "C:/Users/mai_a/Desktop/chromedriver.exe" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
#specify webpage URL
weather_Link = "https://www.wunderground.com/history/monthly/us/dc/arlington-county/KDCA/date/2012-6"

# %% [markdown]
# ### Web Scraping

# %%
#using BeautifulSoup to read the webpage as HTML
page = requests.get(weather_Link).text
soup = BeautifulSoup(page, 'html5lib')

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(weather_Link)

# %%
#display the first 1000 character of HTML 
driver.page_source[:1000]
# Out:
# '<html lang="en" itemscope="" itemtype="http://schema.org/Organization" prefix="og: http://ogp.me/ns#"><head itemscope="" itemtype="http://schema.org/WebSite">\n  <meta charset="utf-8">\n  <title>Arlington County, VA Weather History | Weather Underground</title>\n  <meta name="viewport" content="width=device-width, initial-scale=1">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n  <link rel="dns-prefetch" href="//widgets.outbrain.com">\n  <link rel="dns-prefetch" href="//odb.outbrain.com">\n  <link rel="dns-prefetch" href="//c.amazon-adsystem.com">\n  <link rel="dns-prefetch" href="//s.amazon-adsystem.com">\n  <link rel="dns-prefetch" href="//aax.amazon-adsystem.com">\n  <link rel="dns-prefetch" href="//partner.googleadservices.com">\n  <link rel="dns-prefetch" href="//tpc.googlesyndication.com">\n  <link rel="dns-prefetch" href="//pagead2.googlesyndication.com">\n  <link rel="dns-prefetch" href="//h.nexac.com">\n  <link rel="dns-prefetch" href="//js-sec.indexww.com">\n  <link rel='

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
#locating the table
contents_tbody=soup.find('tbody')

# %%
#displaying the table contents (HTMLcode)
contents_tbody
# Out:
# <tbody _ngcontent-app-root-c207="" class="ng-star-inserted"><tr _ngcontent-app-root-c207="" class="ng-star-inserted"><th _ngcontent-app-root-c207="">Max Temperature</th><td _ngcontent-app-root-c207="" class="ng-star-inserted">104</td><td _ngcontent-app-root-c207="" class="ng-star-inserted">85.27</td><td _ngcontent-app-root-c207="" class="ng-star-inserted">70</td><!-- --></tr><tr _ngcontent-app-root-c207="" class="ng-star-inserted"><th _ngcontent-app-root-c207="">Avg Temperature</th><td _ngcontent-app-root-c207="" class="ng-star-inserted">88.25</td><td _ngcontent-app-root-c207="" class="ng-star-inserted">76.37</td><td _ngcontent-app-root-c207="" class="ng-star-inserted">63.19</td><!-- --></tr><tr _ngcontent-app-root-c207="" class="ng-star-inserted"><th _ngcontent-app-root-c207="">Min Temperature</th><td _ngcontent-app-root-c207="" class="ng-star-inserted">78</td><td _ngcontent-app-root-c207="" class="ng-star-inserted">66.97</td><td _ngcontent-app-root-c207="" class="ng-star-inserted">58</td><!-- --></tr><!-- --></tbody>

# %%
 #locating table columns by class name
soup.find('td', class_ = "ng-star-inserted")
# Out:
# <td _ngcontent-app-root-c207="" class="ng-star-inserted">Max</td>

# %%
#looping over each column in the table to fetch data from the weather webpage
data_time = []
table = soup.find('table', attrs={'class':'days'})
table_body = table.find('tbody')


rows = table_body.find_all('tr')

for row in rows:
    cols = row.find_all('td')
    cols8 = [ele.text.strip() for ele in cols]
    data_time.append([ele for ele in cols8 if ele]) # Get rid of empty values

# %%
#looping over each day in the table
f_MAx=[]
for ddd in data_time:
    if 'Max' not in ddd:
        f_MAx.append(ddd)

# %%
#creating dataframes for each column by specifying index
df1=pd.DataFrame(f_MAx[1:31])
df2=pd.DataFrame(f_MAx[31:61])
df3=pd.DataFrame(f_MAx[61:91])
df4=pd.DataFrame(f_MAx[91:121])
df5=pd.DataFrame(f_MAx[121:151])
df6=pd.DataFrame(f_MAx[151:181])
df7=pd.DataFrame(f_MAx[182:235])

# %%
df1.head()
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
#df1 = df1.iloc[1: , :]
#df1=df1.drop(df1.columns[[0,2]], axis = 1)
#df1

# %%
df2=df2.drop(df2.columns[[0,2]], axis = 1)
df2
# Out:
#        1
# 0   73.6
# 1   68.2
# 2   70.1
# 3   69.6
# 4   63.2
# 5   65.8
# 6   71.2
# 7   74.5
# 8   80.2
# 9   81.3
# 10  80.5
# 11  74.9
# 12  74.5
# 13  73.8
# 14  73.2
# 15  72.7
# 16  69.2
# 17  66.1
# 18  76.9
# 19  86.4
# 20  88.3
# 21  84.7
# 22  81.9
# 23  82.7
# 24  80.3
# 25  72.5
# 26  78.6
# 27  83.5
# 28  87.8
# 29  84.9

# %%
df3=df3.drop(df3.columns[[0,2]], axis = 1)
df3
# Out:
#        1
# 0   66.3
# 1   50.1
# 2   49.1
# 3   49.1
# 4   51.2
# 5   51.4
# 6   51.4
# 7   51.2
# 8   53.9
# 9   61.1
# 10  63.6
# 11  70.4
# 12  57.0
# 13  57.6
# 14  56.2
# 15  52.1
# 16  54.8
# 17  59.4
# 18  66.4
# 19  68.5
# 20  69.5
# 21  67.6
# 22  59.9
# 23  60.0
# 24  58.0
# 25  44.4
# 26  49.1
# 27  56.5
# 28  69.1
# 29  66.8

# %%
df4=df4.drop(df4.columns[[0,2]], axis = 1)
df4
# Out:
#        1
# 0